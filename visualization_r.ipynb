# %%
library(tidyverse)
library(ggplot2)

# %%
game_stat <- read_csv('data/game_statistics.csv')
head(game_stat)
# Out:
# Rows: 722637 Columns: 58
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (4): Team, Date, Name, Pos.
# dbl (54): Game_ID, Season, Is_home, Player_Id, Age, Game_No., TOI_All, TOI_E...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Game_ID    Season   Team Date      Is_home Player_Id Name            Pos.
# 1 2007020001 20072008 ANA  29/9/2007 0       8457261   Brad May        F
# 2 2007020001 20072008 ANA  29/9/2007 0       8458637   Sean O'Donnell  D
# 3 2007020001 20072008 ANA  29/9/2007 0       8459424   Chris Pronger   D
# 4 2007020001 20072008 ANA  29/9/2007 0       8459427   Rob Niedermayer F
# 5 2007020001 20072008 ANA  29/9/2007 0       8459444   Todd Bertuzzi   F
# 6 2007020001 20072008 ANA  29/9/2007 0       8459587   Todd Marchant   F
# ...

# %%
filtered_game_stat <- game_stat |> filter(Team == 'VAN',Season == '20212022', Pos. == 'F')

head(filtered_game_stat)
# Out:
#   Game_ID    Season   Team Date       Is_home Player_Id Name            Pos.
# 1 2021020006 20212022 VAN  13/10/2021 0       8475163   Alex Chiasson   F
# 2 2021020006 20212022 VAN  13/10/2021 0       8475413   Justin Dowling  F
# 3 2021020006 20212022 VAN  13/10/2021 0       8476468   J.T. Miller     F
# 4 2021020006 20212022 VAN  13/10/2021 0       8476871   Tanner Pearson  F
# 5 2021020006 20212022 VAN  13/10/2021 0       8477450   Jason Dickinson F
# 6 2021020006 20212022 VAN  13/10/2021 0       8477500   Bo Horvat       F
#   Age  Game_No. ⋯ SH_xGF SH_xGA    SH_SF SH_SA SH_FF SH_FA SH_CF SH_CA PEN_take
# 1 31.0 1        ⋯ 0      0.0289444 0     2     0     2     0     2     0
# 2 31.0 1        ⋯ 0      0.0000000 0     0     0     0     0     0     0
# 3 28.6 1        ⋯ 0      0.0289444 0     2     0     2     0     2     0
# 4 29.2 1        ⋯ 0      0.0000000 0     0     0     0     0     0     0
# 5 26.3 1        ⋯ 0      0.0000000 0     0     0     0     0     0     0
# ...

# %%
colnames(filtered_game_stat)
# Out:
#  [1] "Game_ID"   "Season"    "Team"      "Date"      "Is_home"   "Player_Id"
#  [7] "Name"      "Pos."      "Age"       "Game_No."  "TOI_All"   "TOI_EV"
# [13] "TOI_PP"    "TOI_SH"    "EV_G"      "EV_A1"     "EV_A2"     "EV_ixG"
# [19] "EV_GF"     "EV_GA"     "EV_xGF"    "EV_xGA"    "EV_SF"     "EV_SA"
# [25] "EV_FF"     "EV_FA"     "EV_CF"     "EV_CA"     "PP_G"      "PP_A1"
# [31] "PP_A2"     "PP_ixG"    "PP_GF"     "PP_GA"     "PP_xGF"    "PP_xGA"
# [37] "PP_SF"     "PP_SA"     "PP_FF"     "PP_FA"     "PP_CF"     "PP_CA"
# [43] "SH_G"      "SH_A1"     "SH_A2"     "SH_ixG"    "SH_GF"     "SH_GA"
# [49] "SH_xGF"    "SH_xGA"    "SH_SF"     "SH_SA"     "SH_FF"     "SH_FA"
# [55] "SH_CF"     "SH_CA"     "PEN_take"  "PEN_draw"

# %%
ggplot(filtered_game_stat,aes(x=Name, y = EV_xGF )) + geom_point() + facet_wrap(~Is_home)
options
# Out:
# function (...)
# .Internal(options(...))
# <bytecode: 0x13414d8d8>
# <environment: namespace:base>
# plot without title
